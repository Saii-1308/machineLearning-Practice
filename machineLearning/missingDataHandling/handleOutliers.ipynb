# %%
#5 number summery

#minimum, maximum,mean,median,standard deviation

import numpy as np
import pandas as pd

# %%
list_marks=[23,53,46,56,78,34,78,89,90,100,45,67,34,56,78,90,23,45,67,89]
minimun,Q1,median,q3,maximum=np.quantile(list_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimun,Q1,median,q3,maximum
# Out:
# (np.float64(23.0),
#  np.float64(45.0),
#  np.float64(61.5),
#  np.float64(80.75),
#  np.float64(100.0))

# %%
IQR=q3-Q1
print(IQR)
# Out:
# 35.75

# %%
lower_fence=Q1-1.5*IQR
upper_fence=q3+1.5*IQR

print(lower_fence,upper_fence)
# Out:
# -8.625 134.375

# %%
import seaborn as sns

sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks=[-20,-89,-90,23,53,46,56,78,34,78,89,90,100,45,67,34,56,78,90,23,45,67,89,300,200]

sns.boxplot(list_marks)
# Out:
# <Axes: >
