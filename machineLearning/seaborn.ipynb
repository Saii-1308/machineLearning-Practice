# %%
import seaborn as sns

# %%
#basic ploting with seborn

tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#create scatter plot-->how data is distributede
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("scatter plot using seaborn")
# Out:
# Text(0.5, 1.0, 'scatter plot using seaborn')

# %%
##line plot

sns.lineplot(x='size',y='total_bill',data=tips,color='red')
plt.title("line plot")
plt.show()

# %%
#bar plot--->categorical plot

sns.barplot(x='day', y='total_bill', data=tips, color='skyblue')
plt.title("bar plot for categorical values")
plt.show()

# %%
#box plot-->IDENTIFY THE OUTLIERS

sns.boxplot(x='day',y='total_bill',data=tips,color='pink')
plt.title('box plot')
plt.show()

# %%
#violin plot--->Understand data distribution (Is it skewed? Bimodal? Symmetrical?)

sns.violinplot(x='day', y='total_bill', data=tips,color='brown')
plt.title("violin plot")
plt.show()

# %%
##histrogram

sns.histplot(tips['total_bill'], bins=10, kde=True)#kernal distributed it show the shape
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#kde plot

sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#relationship between each and every feature
#pairplot

sns.pairplot(tips)

# %%
#heatmap--->we only use the numerical vale

corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd

saled_df=pd.read_csv('sales.csv')
saled_df.head()
# Out:
#          Date InvoiceID CustomerName     Product     Category  Quantity  \
# 0  2023-01-01    INV001     John Doe      Laptop  Electronics         1
# 1  2023-01-02    INV002   Jane Smith  Smartphone  Electronics         2
# 2  2023-01-03    INV003    Tom Hanks  Headphones  Electronics         3
# 3  2023-01-04    INV004     Lisa Ray        Desk    Furniture         1
# 4  2023-01-05    INV005   Amit Kumar       Chair    Furniture         4
#
#    UnitPrice  Total PaymentMethod Region
# 0      55000  55000   Credit Card  North
# 1      20000  40000           UPI   West
# 2       1500   4500          Cash  South
# 3       7000   7000   Net Banking   East
# 4       1500   6000           UPI  North

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Category',y='Total',data=saled_df,estimator=sum)
plt.title('sales data')
plt.xlabel('Category')
plt.ylabel('Total')
plt.show()

# %%
sns.barplot(x='Region', y='Quantity', data=saled_df, estimator=sum)
plt.title('bar plot')
plt.xlabel('Region')
plt.ylabel('Quantity')
plt.show()
